# %% [markdown]
# <a href="https://colab.research.google.com/github/computacao-aplicada/lab01-intro-Rafael-Yuki/blob/main/Aula01_Introducao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 🧠 Exercício
#
# Tente modificar o código acima para:
#
# - Exibir apenas o canal vermelho da imagem.
# - Modifique aleatoriamente o canal vermelho e gere a imagem novamente.
# - Criar uma imagem negativa (inverter as cores).
# - Salvar uma nova imagem modificada no disco.
# - Recorte um pedaço da imagem e salve em disco.
#
# ---

# %%
# Importação das bibliotecas necessárias
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# Exibir gráficos inline
# %matplotlib inline

# %% [markdown]
# ## Exibir apenas o canal vermelho da imagem

# %%
# Mostrar apenas o canal vermelho
red_channel = np.array(r)
plt.imshow(red_channel, cmap='gray')
plt.title("Canal Vermelho")
plt.axis('off')
plt.show()

# %% [markdown]
# ## Modifique aleatoriamente o canal vermelho e gere a imagem novamente

# %%
# Obter arrays dos canais
np_r = np.array(r)
np_g = np.array(g)
np_b = np.array(b)

# Modifica aleatoriamente o canal vermelho
np.random.seed(42)
np_r_mod = np_r.copy()
np_r_mod[:400, :400] = np.random.randint(0, 256, size=(400, 400))

# Gera a imagem modificada
img_mod = Image.merge("RGB", (Image.fromarray(np_r_mod), Image.fromarray(np_g), Image.fromarray(np_b)))

plt.imshow(img_mod)
plt.title("Imagem com Canal Vermelho Modificado")
plt.axis('off')
plt.show()

# %% [markdown]
# ## Criar uma imagem negativa (inverter as cores)

# %%
# Inverter as cores
negative_image = 255 - np_image

plt.imshow(negative_image)
plt.title("Imagem Negativa")
plt.axis('off')
plt.show()

# %% [markdown]
# ## Salvar uma nova imagem modificada no disco

# %%
# Converter imagem negativa para PIL e salvar
negative_pil = Image.fromarray(negative_image)
negative_pil.save("imagem_negativa.jpg")
print("Imagem negativa salva: 'imagem_negativa.jpg'")
# Out:
# Imagem negativa salva: 'imagem_negativa.jpg'

# %% [markdown]
# ## Recorte um pedaço da imagem e salve em disco

# %%
# Recortar imagem (canto superior esquerdo 250x250)
crop = image.crop((0, 0, 250, 250))

# Mostrar recorte
plt.imshow(crop)
plt.title("Recorte da Imagem")
plt.axis('off')
plt.show()

# Salvar recorte
crop.save("recorte_imagem.jpg")
print("Recorte salvo: 'recorte_imagem.jpg'")
# Out:
# Recorte salvo: 'recorte_imagem.jpg'
